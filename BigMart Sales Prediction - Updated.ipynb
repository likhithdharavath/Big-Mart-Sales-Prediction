# %%
#!pip install pandas numpy seaborn matplotlib klib dtale scikit-learn joblib pandas-profiling

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train= pd.read_csv(r'D:\BigMart-Sales-Prediction-With-Deployment\dataset\Train.csv')
df_test= pd.read_csv(r'D:\BigMart-Sales-Prediction-With-Deployment\dataset\Test.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#df_test

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ### Item_Weight is numerical column so we fill it with Mean Imputation

# %%
df_train['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train['Item_Weight'].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %% [markdown]
# ### Outlet_Size is catagorical column so we fill it with Mode Imputation

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# # Selecting features based on general requirements

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# # EDA with Dtale Library

# %%
import dtale

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LENOVO:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA using Pandas Profiling

# %%
pip install --upgrade numba
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'

# %%
pip install --upgrade pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib-1.4.2.dist-info due to invalid metadata entry 'name'

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:8
#       5 import importlib.util
#       6 from warnings import warn
# ----> 8 from ydata_profiling.compare_reports import compare
#       9 from ydata_profiling.controller import pandas_decorator
#      10 from ydata_profiling.profile_report import ProfileReport
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\ydata_profiling\__init__.py:14
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
# ...

# %%
profile = ProfileReport(df_train, title="Pandas Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 profile = ProfileReport(df_train, title="Pandas Profiling Report")
#
# NameError: name 'ProfileReport' is not defined

# %%
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 profile
#
# NameError: name 'profile' is not defined

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_train.corr(),annot=True)
plt.show()
# Out:
# C:\Users\thero\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
#
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # EDA using Klib Library

# %%
import klib

# %%
# klib.describe - functions for visualizing datasets
klib.cat_plot(df_train) # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df_train) # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_32fa1_row0_col0, #T_32fa1_row0_col2, #T_32fa1_row0_col4, #T_32fa1_row1_col1, #T_32fa1_row2_col0, #T_32fa1_row2_col2, #T_32fa1_row2_col3, #T_32fa1_row2_col4, #T_32fa1_row3_col2, #T_32fa1_row3_col3, #T_32fa1_row4_col0, #T_32fa1_row4_col2, #T_32fa1_row4_col4 {
#   color: None;
# }
# #T_32fa1_row0_col1, #T_32fa1_row0_col3, #T_32fa1_row1_col0, #T_32fa1_row1_col2, #T_32fa1_row1_col3, #T_32fa1_row1_col4, #T_32fa1_row2_col1, #T_32fa1_row3_col0, #T_32fa1_row3_col1, #T_32fa1_row3_col4, #T_32fa1_row4_col1, #T_32fa1_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_32fa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32fa1_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_32fa1_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_32fa1_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
# ...

# %%
klib.corr_plot(df_train) # returns a color-encoded heatmap, ideal for correlations
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train) # returns a distribution plot for every numeric feature
# Out:
# c:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# <Axes: xlabel='Item_Weight', ylabel='Density'>

# %%
klib.missingval_plot(df_train) # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.

# %% [markdown]
# # Data Cleaning using Klib Library

# %%
# klib.clean - functions for cleaning datasets
klib.data_cleaning(df_train) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.46 MB (-70.77%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# ...

# %%
klib.clean_column_names(df_train) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float64
#  1   item_fat_content           8523 non-null   object
#  2   item_visibility            8523 non-null   float64
#  3   item_type                  8523 non-null   object
#  4   item_mrp                   8523 non-null   float64
#  5   outlet_establishment_year  8523 non-null   int64
#  6   outlet_size                8523 non-null   object
#  7   outlet_location_type       8523 non-null   object
#  8   outlet_type                8523 non-null   object
#  9   item_outlet_sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 666.0+ KB

# %%
df_train=klib.convert_datatypes(df_train) # converts existing to more efficient dtypes, also called inside data_cleaning()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   float32
# dtypes: category(5), float32(4), int16(1)
# memory usage: 192.9 KB

# %%
klib.mv_col_handling(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# # Preprocessing Task before Model Building

# %% [markdown]
# ## 1) Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_train['Item_Fat_Content']= le.fit_transform(df_train['Item_Fat_Content'])
df_train['Item_Type']= le.fit_transform(df_train['Item_Type'])
df_train['Outlet_Size']= le.fit_transform(df_train['Outlet_Size'])
df_train['Outlet_Location_Type']= le.fit_transform(df_train['Outlet_Location_Type'])
df_train['Outlet_Type']= le.fit_transform(df_train['Outlet_Type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_Fat_Content'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type    item_mrp  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# 8520    10.600000                 1         0.035186          8   85.122398
# 8521     7.210000                 2         0.145221         13  103.133202
# 8522    14.800000                 1         0.044878         14   75.467003
#
# ...

# %% [markdown]
# # 2) Splitting our data into train and test

# %%
X=df_train.drop('Item_Outlet_Sales',axis=1)

# %%
Y=df_train['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=101, test_size=0.2)

# %% [markdown]
# # 3) Standarization

# %%
X.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857646          1.369354         0.066132     7.226681
# std       4.226130          0.644810         0.051598     4.209990
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.310000          1.000000         0.026989     4.000000
# 50%      12.857645          1.000000         0.053931     6.000000
# 75%      16.000000          2.000000         0.094585    10.000000
# max      21.350000          4.000000         0.328391    15.000000
#
#           Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# count  8523.000000                8523.000000  8523.000000
# mean    140.992767                1997.831867     1.170832
# std      62.275051                   8.371760     0.600327
# min      31.290001                1985.000000     0.000000
# 25%      93.826500                1987.000000     1.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
X_train_std= sc.fit_transform(X_train)

# %%
X_test_std= sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 1.52290023, -0.57382672,  0.68469731, ..., -0.25964107,
#         -0.57382672, -0.75847359],
#        [-1.239856  , -0.57382672, -0.09514746, ..., -0.25964107,
#         -0.57382672,  1.60759199],
#        [ 1.54667619,  0.97378032, -0.0083859 , ..., -0.25964107,
#          0.97378032,  0.66116576],
#        ...,
#        [-0.08197109, -0.57382672, -0.91916229, ..., -0.25964107,
#         -0.57382672,  0.18795264],
#        [-0.74888436,  0.97378032,  1.21363045, ..., -0.25964107,
#          0.97378032, -1.70489982],
#        [ 0.67885675, -0.57382672,  1.83915361, ...,  0.98524841,
#         -0.57382672,  0.4245592 ]])

# %%
X_test_std
# Out:
# array([[-0.43860916, -0.57382672, -0.21609253, ...,  0.98524841,
#         -0.57382672,  0.18795264],
#        [ 1.22570184, -0.57382672, -0.52943464, ..., -0.25964107,
#         -0.57382672,  1.37098543],
#        [-1.2184578 ,  0.97378032,  0.16277341, ..., -0.25964107,
#          0.97378032, -1.46829326],
#        ...,
#        [ 0.65508101, -0.57382672,  0.8782423 , ..., -1.50453056,
#         -0.57382672,  0.89777232],
#        [ 1.01171909, -0.57382672, -1.28409256, ...,  0.98524841,
#         -0.57382672,  0.4245592 ],
#        [-1.56558541,  0.97378032, -1.09265374, ..., -0.25964107,
#          0.97378032,  0.66116576]])

# %%
Y_train
# Out:
# 3684     163.786804
# 1935    1607.241211
# 5142    1510.034424
# 4978    1784.343994
# 2299    3558.035156
#            ...
# 599     5502.836914
# 5695    1436.796387
# 8006    2167.844727
# 1361    2700.484863
# 1547     829.586792
# Name: Item_Outlet_Sales, Length: 6818, dtype: float32

# %%
Y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089     872.863770
# 6954    2450.144043
#            ...
# 1317    1721.093018
# 4996     914.809204
# 531      370.184814
# 3891    1358.232056
# 6629    2418.185547
# Name: Item_Outlet_Sales, Length: 1705, dtype: float32

# %%
import joblib

# %%
joblib.dump(sc,r'D:\BigMart-Sales-Prediction-using-Machine- (1)\BigMart-Sales-Prediction-using-Machine-Learning-main\sc.sav')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 joblib.dump(sc,r'D:\BigMart-Sales-Prediction-using-Machine-Learning-main (1)\BigMart-Sales-Prediction-using-Machine-Learning-main\sc.sav')
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:481, in dump(value, filename, compress, protocol, cache_size)
#     479         NumpyPickler(f, protocol=protocol).dump(value)
#     480 elif is_filename:
# --> 481     with open(filename, 'wb') as f:
#     482         NumpyPickler(f, protocol=protocol).dump(value)
#     483 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\BigMart-Sales-Prediction-using-Machine-Learning-main (1)\\BigMart-Sales-Prediction-using-Machine-Learning-main\\sc.sav'

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 8179    11.000000                 1         0.055163          8  100.335800
# 8355    18.000000                 1         0.038979         13  148.641800
# 3411     7.720000                 2         0.074731          1   77.598602
# 7089    20.700001                 1         0.049035          6   39.950600
# 6954     7.550000                 1         0.027225          3  152.934006
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 8179                       2009            1                     2
# 8355                       1987            0                     2
# 3411                       1997            2                     0
# 7089                       2007            1                     1
# 6954                       2002            1                     1
#
#       Outlet_Type  item_fat_content  item_type
# 8179            2                 1          8
# ...

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(Y_test,Y_pred_lr))
print(mean_absolute_error(Y_test,Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_lr)))
# Out:
# 0.5041875773270634
# 880.9999044084498
# 1162.4412631603452

# %%
joblib.dump(lr,r'D:\BigMart-Sales-Prediction-With-Deployment\models\lr.sav')
# Out:
# ['D:\\BigMart-Sales-Prediction-With-Deployment\\models\\lr.sav']

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=1000)

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
print(X_train_std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(X_train_std)
#
# NameError: name 'X_train_std' is not defined

# %%
Y_pred_rf= rf.predict(X_test_std)

# %%
print(r2_score(Y_test,Y_pred_rf))
print(mean_absolute_error(Y_test,Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_rf)))
# Out:
# 0.5506743315271196
# 781.6166588636806
# 1106.6057698698266

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import numpy as np  # Import numpy

# Define the model
model = RandomForestRegressor()

# Define the parameter grid
n_estimators = [10, 100, 1000]
max_depth = range(1, 31)
min_samples_leaf = np.linspace(0.1, 1.0, 10)  # Adjusted to generate 10 values
max_features = ["auto", "sqrt", "log2"]
min_samples_split = np.linspace(0.1, 1.0, 10)  # Adjusted to generate 10 values

# Define grid search parameters
param_grid = {
    'n_estimators': n_estimators,
    'max_depth': max_depth,
    'min_samples_leaf': min_samples_leaf,
    'max_features': max_features,
    'min_samples_split': min_samples_split
}

# Define GridSearchCV
grid_search_forest = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, 
                                  scoring='r2', error_score=0, verbose=2, cv=2)

# Assuming X_train_std and Y_train are your standardized training features and target
# Fit the grid search
grid_search_forest.fit(X_train_std, Y_train)

# Summarize results
print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print(f"{mean:.3f} ({stdev:.3f}) with: {param}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 30
#      25 grid_search_forest = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1,
#      26                                   scoring='r2', error_score=0, verbose=2, cv=2)
#      28 # Assuming X_train_std and Y_train are your standardized training features and target
#      29 # Fit the grid search
# ---> 30 grid_search_forest.fit(X_train_std, Y_train)
#      32 # Summarize results
#      33 print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
#
# NameError: name 'X_train_std' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print(X_train_std)
#
# NameError: name 'X_train_std' is not defined

# %%
grid_search_forest.best_params_
# Out:
# {'n_estimators': 1000}

# %%
grid_search_forest.best_score_
# Out:
# 0.549261909332756

# %%
Y_pred_rf_grid=grid_search_forest.predict(X_test_std)

# %%
r2_score(Y_test,Y_pred_rf_grid)
# Out:
# 0.5490155923062687

# %% [markdown]
# # Save your model

# %%
import joblib

# %%
joblib.dump(grid_search_forest,r'D:\Python37\Projects\iNeuron Intership Projects\ML_BigMart Sales Prediction\models\random_forest_grid.sav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 joblib.dump(grid_search_forest,r'D:\Python37\Projects\iNeuron Intership Projects\ML_BigMart Sales Prediction\models\random_forest_grid.sav')
#
# NameError: name 'grid_search_forest' is not defined

# %%
model=joblib.load(r'D:\Python37\Projects\iNeuron Intership Projects\ML_BigMart Sales Prediction\models\random_forest_grid.sav')
